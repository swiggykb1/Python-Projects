# %%
import pandas as pd
import numpy as np
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
df = pd.read_excel('C:/Users/HP/Downloads/Online Retail.xlsx')
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df['Description'] = df['Description'].str.strip()
df.dropna(axis=0, subset=['InvoiceNo'], inplace=True)
df['InvoiceNo'] = df['InvoiceNo'].astype('str')
df = df[~df['InvoiceNo'].str.contains('C')]
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899          CHILDREN'S APRON DOLLY GIRL         6
# 541906    581587     23254         CHILDRENS CUTLERY DOLLY GIRL         4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138         BAKING SET 9 PIECE RETROSPOT         3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df['Description'].value_counts()
# Out:
# Description
# WHITE HANGING HEART T-LIGHT HOLDER    2327
# JUMBO BAG RED RETROSPOT               2115
# REGENCY CAKESTAND 3 TIER              2019
# PARTY BUNTING                         1707
# LUNCH BAG RED RETROSPOT               1594
#                                       ...
# FLOWER FAIRY 5 SUMMER DRAW LINERS        1
# website fixed                            1
# Found in w/hse                           1
# OOPS ! adjustment                        1
# PAPER CRAFT , LITTLE BIRDIE              1
# Name: count, Length: 4194, dtype: int64

# %%
df['Description'].unique()
# Out:
# array(['WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN',
#        'CREAM CUPID HEARTS COAT HANGER', ..., 'lost',
#        'CREAM HANGING HEART T-LIGHT HOLDER',
#        'PAPER CRAFT , LITTLE BIRDIE'], dtype=object)

# %%
df['Country'].value_counts()
# Out:
# Country
# United Kingdom          487622
# Germany                   9042
# France                    8408
# EIRE                      7894
# Spain                     2485
# Netherlands               2363
# Belgium                   2031
# Switzerland               1967
# Portugal                  1501
# Australia                 1185
# Norway                    1072
# Italy                      758
# Channel Islands            748
# Finland                    685
# Cyprus                     614
# Sweden                     451
# Unspecified                446
# Austria                    398
# Denmark                    380
# Poland                     330
# Japan                      321
# Israel                     295
# Hong Kong                  284
# Singapore                  222
# Iceland                    182
# USA                        179
# Canada                     151
# Greece                     145
# Malta                      112
# United Arab Emirates        68
# ...

# %%
basket_G = (df[df['Country'] == 'Germany'].groupby(['InvoiceNo', 'Description'])['Quantity'].sum().unstack().reset_index().fillna(0).set_index('InvoiceNo'))
basket_F = (df[df['Country'] == 'France'].groupby(['InvoiceNo', 'Description'])['Quantity'].sum().unstack().reset_index().fillna(0).set_index('InvoiceNo'))
basket_UK = (df[df['Country'] == 'United Kingdom'].groupby(['InvoiceNo', 'Description'])['Quantity'].sum().unstack().reset_index().fillna(0).set_index('InvoiceNo'))
basket_Por = (df[df['Country'] == 'Portugal'].groupby(['InvoiceNo', 'Description'])['Quantity'].sum().unstack().reset_index().fillna(0).set_index('InvoiceNo'))
basket_Swe = (df[df['Country'] == 'Sweden'].groupby(['InvoiceNo', 'Description'])['Quantity'].sum().unstack().reset_index().fillna(0).set_index('InvoiceNo'))

# %%
def encode_units(x):
    if x<= 0:
        return 0
    if x >= 1:
        return 1

basket_encoded = basket_G.map(encode_units)
basket_G = basket_encoded

basket_encoded = basket_F.map(encode_units)
basket_F = basket_encoded

basket_encoded = basket_UK.map(encode_units)
basket_UK = basket_encoded

basket_encoded = basket_Por.map(encode_units)
basket_Por = basket_encoded

basket_encoded = basket_Swe.map(encode_units)
basket_Swe = basket_encoded

basket_F.drop('POSTAGE', inplace=True, axis=1)
basket_G.drop('POSTAGE', inplace=True, axis=1)
basket_UK.drop('POSTAGE', inplace=True, axis=1)
basket_Por.drop('POSTAGE', inplace=True, axis=1)
basket_Swe.drop('POSTAGE', inplace=True, axis=1)

# %%
#Apriori
frequent_itemsets = apriori(basket_F, min_support=0.07, use_colnames=True)
rules = association_rules(frequent_itemsets, metric='lift', min_threshold=1)
rules = rules.sort_values(['confidence', 'lift'], ascending = [False, False])
rules
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:109: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#                                           antecedents  \
# 20  (SET/6 RED SPOTTY PAPER CUPS, SET/20 RED RETRO...
# 22  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
# 19                    (SET/6 RED SPOTTY PAPER PLATES)
# 18                      (SET/6 RED SPOTTY PAPER CUPS)
# 2                          (ALARM CLOCK BAKELIKE RED)
# 3                        (ALARM CLOCK BAKELIKE GREEN)
# 21  (SET/6 RED SPOTTY PAPER CUPS, SET/6 RED SPOTTY...
# 17                    (SET/6 RED SPOTTY PAPER PLATES)
# 4                          (ALARM CLOCK BAKELIKE RED)
# 25                    (SET/6 RED SPOTTY PAPER PLATES)
# 16               (SET/20 RED RETROSPOT PAPER NAPKINS)
# ...

# %%
rules[(rules['lift'] >= 3) & (rules['confidence'] >= 0.3)]
# Out:
#                                           antecedents  \
# 20  (SET/6 RED SPOTTY PAPER CUPS, SET/20 RED RETRO...
# 22  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
# 19                    (SET/6 RED SPOTTY PAPER PLATES)
# 18                      (SET/6 RED SPOTTY PAPER CUPS)
# 2                          (ALARM CLOCK BAKELIKE RED)
# 3                        (ALARM CLOCK BAKELIKE GREEN)
# 21  (SET/6 RED SPOTTY PAPER CUPS, SET/6 RED SPOTTY...
# 17                    (SET/6 RED SPOTTY PAPER PLATES)
# 4                          (ALARM CLOCK BAKELIKE RED)
# 25                    (SET/6 RED SPOTTY PAPER PLATES)
# 16               (SET/20 RED RETROSPOT PAPER NAPKINS)
# 15               (SET/20 RED RETROSPOT PAPER NAPKINS)
# 0                        (ALARM CLOCK BAKELIKE GREEN)
# 13                         (PLASTERS IN TIN SPACEBOY)
# 24               (SET/20 RED RETROSPOT PAPER NAPKINS)
# 14                      (SET/6 RED SPOTTY PAPER CUPS)
# ...

# %%
frequent_itemsets = apriori(basket_G, min_support=0.07, use_colnames=True)
rules = association_rules(frequent_itemsets, metric='lift', min_threshold=1)
rules = rules.sort_values(['confidence', 'lift'], ascending = [False, False])
rules
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:109: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#                             antecedents                           consequents  \
# 2   (ROUND SNACK BOXES SET OF 4 FRUITS)  (ROUND SNACK BOXES SET OF4 WOODLAND)
# 4                  (SPACEBOY LUNCH BOX)  (ROUND SNACK BOXES SET OF4 WOODLAND)
# 0    (PLASTERS IN TIN WOODLAND ANIMALS)  (ROUND SNACK BOXES SET OF4 WOODLAND)
# 3  (ROUND SNACK BOXES SET OF4 WOODLAND)   (ROUND SNACK BOXES SET OF 4 FRUITS)
# 1  (ROUND SNACK BOXES SET OF4 WOODLAND)    (PLASTERS IN TIN WOODLAND ANIMALS)
# 5  (ROUND SNACK BOXES SET OF4 WOODLAND)                  (SPACEBOY LUNCH BOX)
#
#    antecedent support  consequent support   support  confidence      lift  \
# ...

# %%
frequent_itemsets = apriori(basket_UK, min_support=0.07, use_colnames=True)
rules = association_rules(frequent_itemsets, metric='lift', min_threshold=1)
rules = rules.sort_values(['confidence', 'lift'], ascending = [False, False])
rules
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:109: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction, zhangs_metric]
# Index: []

# %%
frequent_itemsets = apriori(basket_Por, min_support=0.07, use_colnames=True)
rules = association_rules(frequent_itemsets, metric='lift', min_threshold=1)
rules = rules.sort_values(['confidence', 'lift'], ascending = [False, False])
rules
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:109: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#                                             antecedents  \
# 751   (JUMBO BAG PINK VINTAGE PAISLEY, LUNCH BAG SUK...
# 763   (RED RETROSPOT CHARLOTTE BAG, JUMBO BAG PINK V...
# 930   (JUMBO BAG RED RETROSPOT, LUNCH BAG PINK POLKA...
# 1000  (JUMBO SHOPPER VINTAGE RED PAISLEY, LUNCH BAG ...
# 1013  (JUMBO SHOPPER VINTAGE RED PAISLEY, RED RETROS...
# ...                                                 ...
# 130                   (RETROSPOT TEA SET CERAMIC 11 PC)
# 461                           (LUNCH BAG RED RETROSPOT)
# 110                   (RETROSPOT TEA SET CERAMIC 11 PC)
# 9                             (LUNCH BAG RED RETROSPOT)
# 85                    (RETROSPOT TEA SET CERAMIC 11 PC)
#
# ...

# %%
frequent_itemsets = apriori(basket_Swe, min_support=0.07, use_colnames=True)
rules = association_rules(frequent_itemsets, metric='lift', min_threshold=1)
rules = rules.sort_values(['confidence', 'lift'], ascending = [False, False])
rules
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:109: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#                             antecedents  \
# 12          (TREASURE TIN BUFFALO BILL)
# 13            (BUBBLEGUM RING ASSORTED)
# 14       (TREASURE TIN GYMKHANA DESIGN)
# 15            (BUBBLEGUM RING ASSORTED)
# 28         (MAGIC DRAWING SLATE PURDEY)
# ..                                  ...
# 53   (SET OF 3 CAKE TINS PANTRY DESIGN)
# 61   (SET OF 3 CAKE TINS PANTRY DESIGN)
# 145  (SET OF 3 CAKE TINS PANTRY DESIGN)
# 21   (SET OF 3 CAKE TINS PANTRY DESIGN)
# 41   (SET OF 3 CAKE TINS PANTRY DESIGN)
#
#                                            consequents  antecedent support  \
# 12                           (BUBBLEGUM RING ASSORTED)            0.083333
# ...

# %%
#ECLAT
from apyori import apriori
from mlxtend.frequent_patterns import apriori, association_rules
from mlxtend.preprocessing import TransactionEncoder

dataset = [['Milk', 'Onion', 'Nutmeg', 'Kidney Beans', 'Eggs', 'Yogurt'],
           ['Dill', 'Onion', 'Nutmeg', 'Kidney Beans', 'Eggs', 'Yogurt'],
           ['Milk',],
           ['Milk', 'Unicorn', 'Corn', 'Kidney Beans', 'Yogurt'],
           ['Corn', 'Onion', 'Onion', 'Kidney Beans', 'Ice Cream', 'Eggs']]

# %%
freq_itemsets = pd.DataFrame(dataset)
freq_itemsets
# Out:
#       0        1       2             3          4       5
# 0  Milk    Onion  Nutmeg  Kidney Beans       Eggs  Yogurt
# 1  Dill    Onion  Nutmeg  Kidney Beans       Eggs  Yogurt
# 2  Milk     None    None          None       None    None
# 3  Milk  Unicorn    Corn  Kidney Beans     Yogurt    None
# 4  Corn    Onion   Onion  Kidney Beans  Ice Cream    Eggs

# %%
te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset)
df = pd.DataFrame(te_ary, columns=te.columns_)

# %%
frequent_itemsets = apriori(df, min_support = 0.6, use_colnames=True)
frequent_itemsets
# Out:
#    support                     itemsets
# 0      0.6                       (Eggs)
# 1      0.8               (Kidney Beans)
# 2      0.6                       (Milk)
# 3      0.6                      (Onion)
# 4      0.6                     (Yogurt)
# 5      0.6         (Kidney Beans, Eggs)
# 6      0.6                (Onion, Eggs)
# 7      0.6        (Onion, Kidney Beans)
# 8      0.6       (Yogurt, Kidney Beans)
# 9      0.6  (Kidney Beans, Onion, Eggs)

# %%
rules = association_rules(frequent_itemsets, metric='support', support_only=True, min_threshold=1)
rules
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction, zhangs_metric]
# Index: []

# %%
rules = rules[['antecedents', 'consequents', 'support']]
rules
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, support]
# Index: []
